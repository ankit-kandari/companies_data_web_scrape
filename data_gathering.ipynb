# %%
import pandas as pd
import requests

# %%
url = 'https://api.themoviedb.org/3/tv/top_rated?language=en-US&page=1'
headers = {
    'Authorization': 'Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjYzQzNzM5YzIxZWQ1YWQyYzZjNTc1YTNlMTExNTc0OCIsInN1YiI6IjY1MTY1NzgwZDQ2NTM3MDlkZTVjNWEzMCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.L-3VoBVwg4qkRb3WwgKlXfeG9C2rMzReWRASCaFd-Is',
    'Accept': 'application/json'
}

response = requests.get(url, headers=headers)
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'backdrop_path': '/7BzmK4MWc0cj4hCxwWURt6TS6UR.jpg',
#    'first_air_date': '2023-08-31',
#    'genre_ids': [16, 10765, 10759, 35],
#    'id': 131378,
#    'name': 'Adventure Time: Fionna & Cake',
#    'origin_country': ['US'],
#    'original_language': 'en',
#    'original_name': 'Adventure Time: Fionna & Cake',
#    'overview': 'Fionna and Cake – with the help of the former Ice King, Simon Petrikov - embark on a multiverse-hopping adventure and journey of self-discovery. All the while a powerful new antagonist determined to track them down and erase them from existence, lurks in the shadows.',
#    'popularity': 171.983,
#    'poster_path': '/fi1b6U1kp73xheECzqwzMn8u3mX.jpg',
#    'vote_average': 9.3,
#    'vote_count': 116},
#   {'backdrop_path': '/9faGSFi5jam6pDWGNd0p8JcJgXQ.jpg',
#    'first_air_date': '2008-01-20',
#    'genre_ids': [18, 80],
#    'id': 1396,
#    'name': 'Breaking Bad',
#    'origin_country': ['US'],
#    'original_language': 'en',
# ...

# %%
response.json()["results"]
# Out:
# [{'backdrop_path': '/7BzmK4MWc0cj4hCxwWURt6TS6UR.jpg',
#   'first_air_date': '2023-08-31',
#   'genre_ids': [16, 10765, 10759, 35],
#   'id': 131378,
#   'name': 'Adventure Time: Fionna & Cake',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_name': 'Adventure Time: Fionna & Cake',
#   'overview': 'Fionna and Cake – with the help of the former Ice King, Simon Petrikov - embark on a multiverse-hopping adventure and journey of self-discovery. All the while a powerful new antagonist determined to track them down and erase them from existence, lurks in the shadows.',
#   'popularity': 171.983,
#   'poster_path': '/fi1b6U1kp73xheECzqwzMn8u3mX.jpg',
#   'vote_average': 9.3,
#   'vote_count': 116},
#  {'backdrop_path': '/9faGSFi5jam6pDWGNd0p8JcJgXQ.jpg',
#   'first_air_date': '2008-01-20',
#   'genre_ids': [18, 80],
#   'id': 1396,
#   'name': 'Breaking Bad',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_name': 'Breaking Bad',
# ...

# %%
dff = pd.DataFrame(response.json()["results"])[["id","name","overview","popularity","vote_average","vote_count"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dff = pd.DataFrame(response.json()["results"])[["id","name","overview","popularity","vote_average","vote_count"]]
#
# NameError: name 'response' is not defined

# %%
df.shape
# Out:
# (20, 6)

# %%
dff = pd.DataFrame()

# %%
for i in range(1,553):
    url1 = url.format(i)
    response = requests.get(url1, headers=headers)
    res = pd.DataFrame(response.json()["results"])[["id","name","overview","popularity","vote_average","vote_count"]]
    dff = dff.append(res,ignore_index = True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_14228\1137153636.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dff = dff.append(res,ignore_index = True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_14228\1137153636.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dff = dff.append(res,ignore_index = True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_14228\1137153636.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dff = dff.append(res,ignore_index = True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_14228\1137153636.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dff = dff.append(res,ignore_index = True)
# ...

# %%
dff
# Out:
#           id                              name  \
# 0       1396                      Breaking Bad
# 1      94605                            Arcane
# 2      37854                         One Piece
# 3      60625                    Rick and Morty
# 4      31911  Fullmetal Alchemist: Brotherhood
# ...      ...                               ...
# 11035  31132                      Regular Show
# 11036   1429                   Attack on Titan
# 11037  92685                     The Owl House
# 11038  87108                         Chernobyl
# 11039  72637                              Once
#
#                                                 overview  popularity  \
# 0      When Walter White, a New Mexico chemistry teac...     273.014
# 1      Amid the stark discord of twin cities Piltover...      75.224
# 2      Years ago, the fearsome Pirate King, Gol D. Ro...     122.987
# 3      Rick is a mentally-unbalanced but scientifical...     441.992
# ...

# %%
dff.to_csv("movies1.csv")

# %%
pd.read_csv("movies1.csv")
# Out:
#        Unnamed: 0     id                              name  \
# 0               0   1396                      Breaking Bad
# 1               1  94605                            Arcane
# 2               2  37854                         One Piece
# 3               3  60625                    Rick and Morty
# 4               4  31911  Fullmetal Alchemist: Brotherhood
# ...           ...    ...                               ...
# 11035       11035  31132                      Regular Show
# 11036       11036   1429                   Attack on Titan
# 11037       11037  92685                     The Owl House
# 11038       11038  87108                         Chernobyl
# 11039       11039  72637                              Once
#
#                                                 overview  popularity  \
# 0      When Walter White, a New Mexico chemistry teac...     273.014
# 1      Amid the stark discord of twin cities Piltover...      75.224
# ...
